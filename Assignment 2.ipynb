# %% [markdown]
# # **Lists**

# %% [markdown]
# Q1. Create a list of 5 random numbers and print the list.

# %%
num=[10,20,30,40,50]
print("Numbers list:",num)
# Out:
# Numbers list: [10, 20, 30, 40, 50]

# %% [markdown]
# Q2. Insert 3 new values to the list and print the updated list.

# %%
num=[10,20,30,40,50]
num[5:7]=[60,70,80]
print("Updated List:",num)
# Out:
# Updated List: [10, 20, 30, 40, 50, 60, 70, 80]

# %% [markdown]
# Q3. Try to use a for loop to print each element in the list.

# %%
num=[10,20,30,40,50,60,70,80]
for i in num:
  print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80

# %% [markdown]
# # **Dictionary**

# %% [markdown]
# Q1.Create a dictionary with keys 'name', 'age', and 'address' and values 'John', 25, and 'New York' respectively.

# %%
Details={"Name":"John",
         "Age":25,
         "Address":"New York"}
print("Details_Dictionary:",Details)
# Out:
# Details_Dictionary: {'Name': 'John', 'Age': 25, 'Address': 'New York'}

# %% [markdown]
# Q2. Add a new key-value pair to the dictionary created in Q1 with key 'phone' and value '1234567890'.

# %%
Details['Phone']=1234567890
print("Updated Details:",Details)
# Out:
# Updated Details: {'Name': 'John', 'Age': 25, 'Address': 'New York', 'Phone': 1234567890}

# %% [markdown]
# # **Set**

# %% [markdown]
# Q1.Create a set with values 1, 2, 3, 4, and 5.

# %%
number_sets={1,2,3,4,5}
print("Numbers_set:",number_sets)
# Out:
# Numbers_set: {1, 2, 3, 4, 5}

# %% [markdown]
# Q2. Add the value 6 to the set created in Q1.

# %%
number_sets={1,2,3,4,5}
number_sets.add(6)
print("Updated Numbers_set:",number_sets)
# Out:
# Updated Numbers_set: {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Q3. Remove the value 3 from the set created in Q1.

# %%
number_sets={1,2,3,4,5,6}
number_sets.remove(3)
print("Updated numbers_set:",number_sets)
# Out:
# Updated numbers_set: {1, 2, 4, 5, 6}

# %% [markdown]
# # **Tuple**

# %% [markdown]
# Q1. Create a tuple with values 1, 2, 3, and 4

# %%
T1=(1,2,3,4)
print(type(T1))
print("Tuple:",T1)
# Out:
# <class 'tuple'>
# Tuple: (1, 2, 3, 4)

# %% [markdown]
# Q2. Print the length of the tuple created in Q1.

# %%
T1=(1,2,3,4)
length=len(T1)
print("Length of the tuple:",length)
# Out:
# Length of the tuple: 4
